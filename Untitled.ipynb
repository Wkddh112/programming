# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
lottegiants= pd.read_html('https://ko.wikipedia.org/wiki/%EB%A1%AF%EB%8D%B0_%EC%9E%90%EC%9D%B4%EC%96%B8%EC%B8%A0')
lottegiants[0]
# Out:
#                                           0  \
# 0                       롯데 자이언츠Lotte Giants
# 1                                       NaN
# 2                                       회사명
# 3                                     설립 연도
# 4                                      마스코트
# 5                                     소속 리그
# 6                     1군:KBO 리그2군:KBO 퓨처스리그
# 7                                      홈 구장
# 8                     사직야구장, 울산문수야구장(제2홈구장)
# 9                                    이전 홈구장
# 10                                    영구 결번
# 11                                   11 최동원
# 12                                   역대 타이틀
# 13                               시리즈 우승(2회)
# 14                                1984･1992
# 15                                리그 우승(0회)
# 16                                1984 후기리그
# 17                               성적(타이틀 이외)
# 18                 시리즈 출장(4회)(굵은 글씨는 승리한 해)
# 19                      1984･1992･1995･1999
# ...

# %%
lottegiants= pd.read_html('https://ko.wikipedia.org/wiki/%EB%A1%AF%EB%8D%B0_%EC%9E%90%EC%9D%B4%EC%96%B8%EC%B8%A0')
lottegiants[2]
# Out:
#               연도            팀명            순위     승     패    무     승률  \
# 0           1982            롯데   전기 5위 후기 5위    31    49    0  0.388
# 1           1983            롯데   전기 4위 후기 6위    43    56    1  0.434
# 2           1984            롯데            1위    50    48    2  0.510
# 3           1985            롯데   전기 4위 후기 2위    59    51    0  0.536
# 4           1986            롯데   전기 3위 후기 5위    50    52    6  0.490
# 5           1987            롯데   전기 4위 후기 3위    54    49    5  0.523
# 6           1988            롯데   전기 4위 후기 3위    57    49    2  0.537
# 7           1989            롯데            7위    48    67    5  0.421
# 8           1990            롯데            6위    44    71    4  0.388
# 9           1991            롯데            4위    61    62    3  0.496
# 10          1992            롯데            1위    71    55    1  0.563
# 11          1993            롯데            6위    62    63    1  0.496
# 12          1994            롯데            6위    56    67    3  0.456
# ...

# %%
bt.team = pd.read_csv("Documents/p")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-60b7835c2938> in <module>
# ----> 1 picher = pd.read_csv("Documents/picher_lt.csv", encoding='cp949')
#       2 picher
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-12ec412d968a> in <module>
# ----> 1 lottegiants["순위"].hist(bins=30)
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2d72d41d5f6b> in <module>
# ----> 1 lottegiants.head()
#
# AttributeError: 'list' object has no attribute 'head'
